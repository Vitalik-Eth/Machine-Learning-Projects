# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Скачивание и распаковка данных

# %%
! wget "https://s360sas.storage.yandex.net/rdisk/2a3e8f16be6111fc59c5ef304995dddfcd524c0ff149cf3d94ac2a9c52030250/604155e2/BaOcgBJYwIzg6Pz-7e1ofcxFHdmkN3oiKrFK6mtESs3xZvt_QDrEJUyDMBrgHKnxnXLXuScBNzCTfz8qBKWv9g==?uid=316082386&filename=ml5.zip&disposition=attachment&hash=&limit=0&content_type=application%2Fx-zip-compressed&owner_uid=316082386&fsize=1062748&hid=a13244ba9ebd056c2470d6af88528ec6&media_type=compressed&tknv=v2&etag=93ea8519075d5abce2ba94c210af7aa8&rtoken=mAHuIDal1Rr6&force_default=yes&ycrid=na-2af6e617e08416dfb31c3cb49c4580a1-downloader18f&ts=5bcbcf0b7bc80&s=b22ff249c4e86c74b145f82e99b078212b1a9f96d1691fbbd26c8f715b192eca&pb=U2FsdGVkX19a9V3__4mIL6jz5nyDV_DgEPsTY7saQdERPk8uHFvN70FkyQGf3iCIZGlzR2Zfm2kGNZR4AAWi9iQ6uRtDK2_pHDcPX3skHaU" -O data.zip

# %%
! unzip data.zip

# %%
! ls ml5

# %% [markdown]
# ## Загрузим данные в память и посмотрим на них
#
# Эти данные — для задачи классификации людей на два класса: те, у кого будут сердечно-сосудистые заболевания, и те, у кого не будут.
#
# Признаки:
# - пост
# - вес
# - верхнее артериальное давление
# - нижнее артериальное давление
# - уровень холестерина
# - уровень глюкозы
# - курит ли человек
# - пьет ли человек алкоголь
# - высокий ли уровень активности у человека в течение дня.
#
# Целевая переменная: cardio: будет ли у человека сердечно-сосудистое заболевание в ближайшем будущем.

# %%
data = pd.read_csv('ml5/train.csv', delimiter=';')
data.head()

# %% [markdown]
# ## Задание #0:
#
# Выведите информацию о датасете. Есть ли пропуски в данных? Есть ли в данных категориальные переменные?

# %%
<ТУТ ВАШ КОД>

# %% [markdown]
# ## Задание #1:
#
# Разбейте датасет на два: один, в котором будут строки с cardio=0, второй — в котором строки с cardio=1

# %%
data_0 = <ТУТ ВАШ КОД>
data_1 = <ТУТ ВАШ КОД>

# %% [markdown]
# ## Задание #2:
#
# Постройте гистограммы всех признаков для датасетов data_0 и data_1

# %%
<ТУТ ВАШ КОД>

# %% [markdown]
# Что вы видите на гистограммах? Есть ли явные отличия в распределениях признаков для данных data_0 и data_1?

# %% [markdown]
# ## Задание #3:

# %% [markdown]
# Выведите:
#
# - информацию о нижнем артериальном давлении (ap_lo) и верхнем артериальном давлении (ap_hi) для каждого из двух датасетов data_0 и data_1. Подсказка: воспользуйтесь функцией .info()
#
# - количество курящих людей среди тех, у кого есть ССЗ (т.е. у кого cardio=1)
#
# - количество курящих людей среди тех, у кого нет ССЗ (т.е. у кого cardio=0)
#
# - количество курящих и пьющих людей среди тех, у кого есть ССЗ (т.е. у кого cardio=1)
#
# - количество курящих и пьющих людей среди тех, у кого нет ССЗ (т.е. у кого cardio=0)

# %%
<ТУТ ВАШ КОД>

# %% [markdown]
# ## Задание #4:
#
# Как видим, в колонке age возраст указан не в горах, а в днях. Переведите колонку age в формат дней. То есть, чтобы в data в колонке age возраст был выражен в годах.

# %%
<ТУТ ВАШ КОД>
